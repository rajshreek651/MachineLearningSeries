# %% [markdown]
# # Simple Linear Regression
# Linear Regression is used when I/P(Independent) data has LINEAR relationship with O/P(Dependent) data
#
# Simple Linear Regression is used when there is only 'ONE independent variable' on which the 'dependent variable' depends
#
# ##### Algorithm based on:
# y = mx + c

# %%
# Aim of the Experiment
# To build a machine learning model that can 'predict salary' based on 'years of experience' using Linear Regression.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\user\AppData\Roaming\Python\Python313\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df = pd.read_csv("Salary_Data.csv")
df.head(2)
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205

# %%
# Analyzing the dataset
# Need to apply regression here, coz O/P: Salary is 'CONTINUOUS NUMERICAL' in nature

# %%
sns.scatterplot(x="YearsExperience", y="Salary", data=df)
plt.show()

# %% [markdown]
# ### We observe that the graph follows simple linearity, so we should apply 'Simple Linear Regression'

# %%
# checking for missing values
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
# checking duplicate rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# So, our Dataset is totally neat and clean

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 612.0 bytes

# %%
# Test-Train Split
x = df[["YearsExperience"]] # We used [[]], coz we should APPLY ML algos. in 2D dataset
# If multiple columns were passed then there was no need to apply double brackets [[]]

# 1D will work for dependent variable 'y'
y = df["Salary"]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=100) # 'random_state' to be changed(decrease or increase from 0 to so on based on dataset shape) if the accuracy improves

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((24, 1), (24,), (6, 1), (6,))

# %% [markdown]
# # * Applying ML model

# %%
from sklearn.linear_model import LinearRegression
# sklearn --> module
# linear_model --> sub module
# LinearRegression --> class

# %%
# LinearRegression --> class, so we need to make its object
lr = LinearRegression()
lr.fit(x_train, y_train) # Whatever data is given to fit, i.e. to train, the model will be trained on y = mx + c
# Out:
# LinearRegression()

# %% [markdown]
# #### Training model on y = mx + c, means finding best value for 'm' & 'c' which fits the model, to give the 'BEST FIT LINE'
# #### 'BEST FIT LINE' --> the line which passes from the very mid of the data points,
# #### in order to get the better prediction
# #### PREDICTION IS DONE BASED ON THAT REGRESSION LINE

# %% [markdown]
# # Checking Model Accuracy

# %%
lr.score(x_test, y_test) * 100 # finding in %, so multiplying with 100
# Out:
# 97.20725422361338

# %%
# Gives best accuracy --> about 97% when 'random_state=100'

# %% [markdown]
# # Finding Best values for 'm' and 'c' for y = m*x + c

# %%
lr.coef_
# gives the best value of 'm' for 'y=mx+c'
# slope value is +ve, means acute angle formed with +ve x-axis
# Out:
# array([9361.11639032])

# %%
lr.intercept_ 
# gives the best value of 'c' for 'y=mx+c'
# intercept value is +ve, means regression line passes through +ve y-axis (i.e, makes +ve intercept)
# Out:
# np.float64(26819.06511870089)

# %% [markdown]
# # Putting those constant values in the eqn y = m*x + c

# %%
# y = m*x + c
# y = (9361.11639032 * x) + (26819.06511870089)

# %%
# Checking by passing the value of 'x', here let x=1.1
(9361.11639032 * 1.1) + (26819.06511870089)
# Out:
# 37116.29314805289

# %%
lr.predict([[1.1]]) # Making the prediction
# Out:
# C:\Users\user\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([37116.29314805])

# %%
y_pred = lr.predict(x)

# %%
sns.scatterplot(x="YearsExperience", y="Salary", data=df)
plt.plot(df["YearsExperience"], y_pred, color="red")
plt.legend(["org data points", "prediction line"])
plt.savefig("LinearPrediction.jpg")
plt.show()

# %%
lr.predict([[1.1]])
# Out:
# C:\Users\user\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([37116.29314805])
